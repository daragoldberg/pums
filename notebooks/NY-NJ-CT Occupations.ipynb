# %% [markdown]
# ### Using IPUMS records, calculate life sciences occupations

# %%
import pandas as pd
import numpy as np
import math

# %%
# allow max rows and colums to be displayed
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Stat functions for using replicate weights

# %%
# functions to calculate standard error, moe, and coefficient of variation
def get_se(per_wt,rep_weights):
    result = math.sqrt((sum(map(lambda x: (x-per_wt)**2,rep_weights))/20))
    return result

def get_moe(se):
    return se*1.645 #90% confidence interval

def agg_moe(m):
    result = math.sqrt(sum(map(lambda x: x**2, m)))
    return result

def get_cv(est,m):
    if est == 0:
        return 0
    else:
        return (np.absolute(m/1.645/est))*100

# %%
# create a list of replicate weights
repwt = 'REPWTP'
repwts = [repwt+str(i) for i in range(1, 81)]

# %% [markdown]
# #### Geography look up files & cleanup

# %%
# pull in geography reference files
df = pd.read_csv('../data/occ_pums.csv')
respuma_00 = pd.read_csv('../data/respuma_xwalk_00.csv')
respuma_10 = pd.read_csv('../data/respuma_xwalk_10.csv')

# %%
respuma_10.head()
# Out:
#    StateFIPS  PUMA  GEOID10  \
# 0          9   100   900100
# 1          9   101   900101
# 2          9   102   900102
# 3          9   103   900103
# 4          9   104   900104
#
#                                                 NAME Subregion Subregion2  \
# 0  Danbury, Ridgefield, Bethel, Brookfield, New F...        CT         CT
# 1  Fairfield, New Canaan, Wilton, Weston & Easton...        CT         CT
# 2                    Stamford & Greenwich Towns PUMA        CT         CT
# 3              Norwalk, Westport & Darien Towns PUMA        CT         CT
# 4                               Bridgeport Town PUMA        CT         CT
#
#    Region     County  CountyFIPS
# 0  Region  Fairfield        9001
# 1  Region  Fairfield        9001
# 2  Region  Fairfield        9001
# 3  Region  Fairfield        9001
# 4  Region  Fairfield        9001

# %%
respuma_00.GISMATCH=respuma_00.GISMATCH.apply(str)
respuma_10.GEOID10=respuma_10.GEOID10.apply(str)

# %%
# create a new id columns for merge with geo lookup tables
df['stpuma_id'] = df['STATEFIP'].apply(str) + \
                    df['PUMA'].apply(str).apply(lambda x: '{0:0>5}'.format(x))

# %%
df.dtypes
# Out:
# YEAR           int64
# MULTYEAR       int64
# SAMPLE         int64
# SERIAL         int64
# CBSERIAL       int64
# HHWT         float64
# CLUSTER        int64
# STATEFIP       int64
# COUNTYFIP      int64
# METRO          int64
# CITY           int64
# PUMA           int64
# STRATA         int64
# GQ             int64
# PERNUM         int64
# PERWT        float64
# REPWTP         int64
# AGE            int64
# EDUC           int64
# EDUCD          int64
# CLASSWKR       int64
# CLASSWKRD      int64
# OCC            int64
# OCCSOC        object
# IND            int64
# INDNAICS      object
# INCWAGE        int64
# PWSTATE2       int64
# PWCOUNTY       int64
# PWPUMA00       int64
# TRANWORK       int64
# REPWTP1        int64
# REPWTP2        int64
# REPWTP3        int64
# REPWTP4        int64
# REPWTP5        int64
# REPWTP6        int64
# REPWTP7        int64
# REPWTP8        int64
# REPWTP9        int64
# REPWTP10       int64
# REPWTP11       int64
# REPWTP12       int64
# REPWTP13       int64
# REPWTP14       int64
# REPWTP15       int64
# REPWTP16       int64
# REPWTP17       int64
# REPWTP18       int64
# REPWTP19       int64
# REPWTP20       int64
# REPWTP21       int64
# REPWTP22       int64
# REPWTP23       int64
# REPWTP24       int64
# REPWTP25       int64
# REPWTP26       int64
# REPWTP27       int64
# REPWTP28       int64
# REPWTP29       int64
# REPWTP30       int64
# REPWTP31       int64
# REPWTP32       int64
# REPWTP33       int64
# REPWTP34       int64
# REPWTP35       int64
# REPWTP36       int64
# REPWTP37       int64
# REPWTP38       int64
# REPWTP39       int64
# REPWTP40       int64
# REPWTP41       int64
# REPWTP42       int64
# REPWTP43       int64
# REPWTP44       int64
# REPWTP45       int64
# REPWTP46       int64
# REPWTP47       int64
# REPWTP48       int64
# REPWTP49       int64
# REPWTP50       int64
# REPWTP51       int64
# REPWTP52       int64
# REPWTP53       int64
# REPWTP54       int64
# REPWTP55       int64
# REPWTP56       int64
# REPWTP57       int64
# REPWTP58       int64
# REPWTP59       int64
# REPWTP60       int64
# REPWTP61       int64
# REPWTP62       int64
# REPWTP63       int64
# REPWTP64       int64
# REPWTP65       int64
# REPWTP66       int64
# REPWTP67       int64
# REPWTP68       int64
# REPWTP69       int64
# REPWTP70       int64
# REPWTP71       int64
# REPWTP72       int64
# REPWTP73       int64
# REPWTP74       int64
# REPWTP75       int64
# REPWTP76       int64
# REPWTP77       int64
# REPWTP78       int64
# REPWTP79       int64
# REPWTP80       int64
# stpuma_id     object
# dtype: object

# %%
#separate by year
df_10 = df[df.YEAR==2010]
df_19 = df[df.YEAR==2019]

# %%
reg_10 = pd.merge(df_10,respuma_00,how='left',left_on='stpuma_id',right_on='GISMATCH')
reg_19 = pd.merge(df_19,respuma_10,how='left',left_on='stpuma_id',right_on='GEOID10')

# %%
reg_10 = reg_10.dropna(subset=['Subregion'])
reg_10.head()
# Out:
#    YEAR  MULTYEAR  SAMPLE   SERIAL       CBSERIAL  HHWT        CLUSTER  \
# 5  2010      2006  201005  1085609  2006000000586  40.0  2010010856095
# 6  2010      2006  201005  1085610  2006000000750  35.0  2010010856105
# 7  2010      2006  201005  1085610  2006000000750  35.0  2010010856105
# 8  2010      2006  201005  1085611  2006000001050  21.0  2010010856115
# 9  2010      2006  201005  1085611  2006000001050  21.0  2010010856115
#
#    STATEFIP_x  COUNTYFIP  METRO  CITY  PUMA_x  STRATA  GQ  PERNUM  PERWT  \
# 5           9          5      0     0     100   10009   3       1   40.0
# 6           9          9      2  7250    1900  190009   1       1   35.0
# 7           9          9      2  7250    1900  190009   1       2   35.0
# 8           9          9      2  7250    1900  190009   1       1   21.0
# 9           9          9      2  7250    1900  190009   1       2   21.0
#
#    REPWTP  AGE  EDUC  EDUCD  CLASSWKR  CLASSWKRD   OCC  OCCSOC   IND  \
# 5       1   94     2     24         0          0     0       0     0
# 6       1   50     6     62         0          0     0       0     0
# 7       1   75     6     62         0          0     0       0     0
# 8       1   28    10    101         2         22  5240  434051  2190
# 9       1   30    10    101         2         22  1960  1940XX  7290
#
#    INDNAICS  INCWAGE  PWSTATE2  PWCOUNTY  PWPUMA00  TRANWORK  REPWTP1  \
# 5         0        0         0         0         0         0       12
# 6         0        0         0         0         0         0       14
# 7         0        0         0         0         0         0       12
# 8  3254        50836         9         1      2100        10        8
# 9  5413        47592         9         9      1500        10        8
#
#    REPWTP2  REPWTP3  REPWTP4  REPWTP5  REPWTP6  REPWTP7  REPWTP8  REPWTP9  \
# 5       12       40       12       70       40       39       40       68
# 6       32       18       15       37       12       53       39       33
# 7       32       17       15       37       12       54       37       33
# 8       34       25       23       19        6       37       21       17
# 9       36       23       22       19        7       36       21       19
#
#    REPWTP10  REPWTP11  REPWTP12  REPWTP13  REPWTP14  REPWTP15  REPWTP16  \
# 5        39        12        40        72        71        39        42
# 6        38        64        39        12        42        51        48
# 7        37        64        38        11        43        49        47
# 8         8        24         8         8        28        43        22
# 9         7        21         8         8        28        43        22
#
#    REPWTP17  REPWTP18  REPWTP19  REPWTP20  REPWTP21  REPWTP22  REPWTP23  \
# 5        66        12        43        42        68        66        38
# 6        30        30        65        33        12        35        14
# 7        29        29        65        29        10        35        14
# 8        15        27        19        33         5        34        25
# 9        13        25        20        33         5        34        24
#
#    REPWTP24  REPWTP25  REPWTP26  REPWTP27  REPWTP28  REPWTP29  REPWTP30  \
# 5        70        12        39        39        41        13        39
# 6        12        35        13        50        44        36        38
# 7        10        33        13        49        40        36        35
# 8        24        26         7        32        23        21         8
# 9        25        27         8        32        21        19         8
#
#    REPWTP31  REPWTP32  REPWTP33  REPWTP34  REPWTP35  REPWTP36  REPWTP37  \
# 5        68        41        12        12        41        42        12
# 6        53        36        15        39        79        60        28
# 7        52        36        14        41        79        58        29
# 8        21        10         9        27        38        25        21
# 9        22         8         7        27        38        27        22
#
#    REPWTP38  REPWTP39  REPWTP40  REPWTP41  REPWTP42  REPWTP43  REPWTP44  \
# 5        70        41        41        66        69        39        70
# 6        28        60        35        54        34        65        58
# 7        28        56        33        55        33        62        54
# 8        23        17        36         7        26        19        22
# 9        25        15        39         7        26        18        23
#
#    REPWTP45  REPWTP46  REPWTP47  REPWTP48  REPWTP49  REPWTP50  REPWTP51  \
# 5        13        40        39        39        12        39        69
# 6        36        44        11        39        31        40        12
# 7        34        46        13        36        28        37        13
# 8        23         9        31        26        23         9        19
# 9        25         9        30        27        22        10        20
#
#    REPWTP52  REPWTP53  REPWTP54  REPWTP55  REPWTP56  REPWTP57  REPWTP58  \
# 5        41        12        12        39        41        12        71
# 6        36        60        45        10         9        31        34
# 7        39        60        41        12        11        29        33
# 8         8         7        37        39        20        23        27
# 9         7         6        36        39        20        21        29
#
#    REPWTP59  REPWTP60  REPWTP61  REPWTP62  REPWTP63  REPWTP64  REPWTP65  \
# 5        41        41        11        12        38        12        70
# 6        16        31        58        32        59        59        32
# 7        16        30        54        30        58        59        31
# 8        22        40         8        31        21        23        19
# 9        20        41        11        27        20        22        18
#
#    REPWTP66  REPWTP67  REPWTP68  REPWTP69  REPWTP70  REPWTP71  REPWTP72  \
# 5        39        38        40        69        40        12        41
# 6        59        12        37        41        36        12        33
# 7        56        12        38        40        33        13        33
# 8         6        33        22        20         8        22         7
# 9         6        31        21        20         8        28         7
#
#    REPWTP73  REPWTP74  REPWTP75  REPWTP76  REPWTP77  REPWTP78  REPWTP79  \
# 5        70        72        41        42        69        12        41
# 6        75        36        18        12        31        39        10
# 7        73        38        16        13        31        36        11
# 8         8        32        31        20        18        22        26
# 9         8        33        32        19        15        24        25
#
#    REPWTP80 stpuma_id    StateName  STATEFIP_y  PUMA_y    GISJOIN GISMATCH  \
# 5        41    900100  Connecticut         9.0   100.0  G09000100   900100
# 6        29    901900  Connecticut         9.0  1900.0  G09001900   901900
# 7        32    901900  Connecticut         9.0  1900.0  G09001900   901900
# 8        32    901900  Connecticut         9.0  1900.0  G09001900   901900
# 9        34    901900  Connecticut         9.0  1900.0  G09001900   901900
#
#    CountyCode  CountyName Subregion
# 5      9005.0  Litchfield        CT
# 6      9009.0   New Haven        CT
# 7      9009.0   New Haven        CT
# 8      9009.0   New Haven        CT
# 9      9009.0   New Haven        CT

# %%
reg_19 = reg_19.dropna(subset=['Region'])
reg_19.head()
# Out:
#     YEAR  MULTYEAR  SAMPLE   SERIAL       CBSERIAL  HHWT        CLUSTER  \
# 1   2019      2015  201903  1211600  2015000000641  12.0  2019012116003
# 2   2019      2015  201903  1211601  2015000000837  12.0  2019012116013
# 3   2019      2015  201903  1211601  2015000000837  12.0  2019012116013
# 9   2019      2015  201903  1211603  2015000001026  13.0  2019012116033
# 10  2019      2015  201903  1211603  2015000001026  13.0  2019012116033
#
#     STATEFIP  COUNTYFIP  METRO  CITY  PUMA_x  STRATA  GQ  PERNUM  PERWT  \
# 1          9          5      1     0     500   50009   1       1   12.0
# 2          9          1      4     0     100   10009   1       1   13.0
# 3          9          1      4     0     100   10009   1       2   14.0
# 9          9          1      4     0     105   10509   1       1   13.0
# 10         9          1      4     0     105   10509   1       2   12.0
#
#     REPWTP  AGE  EDUC  EDUCD  CLASSWKR  CLASSWKRD   OCC  OCCSOC   IND  \
# 1        1   83     7     71         0          0     0       0     0
# 2        1   66    10    101         2         28  3255  291141  7860
# 3        1   68    11    115         1         13  3010  291020  7980
# 9        1   35    11    114         2         22  1105  151244  7280
# 10       1   31    11    114         2         22   120  113031  6480
#
#     INDNAICS  INCWAGE  PWSTATE2  PWCOUNTY  PWPUMA00  TRANWORK  REPWTP1  \
# 1          0        0         0         0         0         0       10
# 2   6111        37769         9         1       100        10       13
# 3   6212       710052         9         1       100        10       13
# 9   5412        91724         9         1       100        10        4
# 10  5111Z       70142         9         1       100        10        4
#
#     REPWTP2  REPWTP3  REPWTP4  REPWTP5  REPWTP6  REPWTP7  REPWTP8  REPWTP9  \
# 1        10       24        3       20       10        3        4        3
# 2        22       13       12       22       13       23        4        4
# 3        21       14       13       24       13       22        4        3
# 9        23       13       23       12       12       19       12       22
# 10       22       12       20       13       11       19       11       20
#
#     REPWTP10  REPWTP11  REPWTP12  REPWTP13  REPWTP14  REPWTP15  REPWTP16  \
# 1         12        18         4        14        12        13        11
# 2         13        12        13        20        11         4        13
# 3         14        14        14        21        14         5        14
# 9          4         4        13        12        14        22        14
# 10         3         4        11        12        13        22        12
#
#     REPWTP17  REPWTP18  REPWTP19  REPWTP20  REPWTP21  REPWTP22  REPWTP23  \
# 1         19        22        11        12        11        12        20
# 2          4         4        22        13        11        20        13
# 3          4         4        23        13        13        21        14
# 9          3        12         4        13         4        24        12
# 10         3        11         3        12         3        24        12
#
#     REPWTP24  REPWTP25  REPWTP26  REPWTP27  REPWTP28  REPWTP29  REPWTP30  \
# 1          3        21        12         4         4         3        12
# 2         13        21        12        21         3         3        13
# 3         13        23        13        23         4         3        14
# 9         23        12        11        23        13        20         4
# 10        18        12        12        20        11        19         3
#
#     REPWTP31  REPWTP32  REPWTP33  REPWTP34  REPWTP35  REPWTP36  REPWTP37  \
# 1         17         4        11        13        11        13        20
# 2         13        13        22        12         3        14         4
# 3         14        13        24        14         3        14         4
# 9          3        12        15        13        21        11         4
# 10         3        11        13        14        21        12         4
#
#     REPWTP38  REPWTP39  REPWTP40  REPWTP41  REPWTP42  REPWTP43  REPWTP44  \
# 1         17        14        12        12        12        22         4
# 2          3        22        12        13        21        14        14
# 3          4        23        14        13        22        14        15
# 9         14         3        12         4        21        13        22
# 10        13         4        13         4        18        13        18
#
#     REPWTP45  REPWTP46  REPWTP47  REPWTP48  REPWTP49  REPWTP50  REPWTP51  \
# 1         20        12         4         4         3        13        19
# 2         24        11        20         4         4        13        13
# 3         26        11        21         3         4        14        14
# 9         12        12        19        12        22         4         3
# 10        10        11        19        11        21         4         4
#
#     REPWTP52  REPWTP53  REPWTP54  REPWTP55  REPWTP56  REPWTP57  REPWTP58  \
# 1          3        12        10        12        12        20        21
# 2         12        22        12         4        13         4         4
# 3         14        21        13         4        14         4         4
# 9         12        14        12        21        14         4        13
# 10        11        14        12        21        13         3        12
#
#     REPWTP59  REPWTP60  REPWTP61  REPWTP62  REPWTP63  REPWTP64  REPWTP65  \
# 1         12        10        11        12        18         4        20
# 2         20        13        12        22        13        12        21
# 3         24        13        14        23        14        13        20
# 9          4        12         4        21        13        24        13
# 10         4        12         3        21        11        25        13
#
#     REPWTP66  REPWTP67  REPWTP68  REPWTP69  REPWTP70  REPWTP71  REPWTP72  \
# 1         13         3         4         3        12        22         4
# 2         13        21         4         3        12        14        13
# 3         15        23         4         3        12        15        13
# 9         14        24        14        22         4         3        14
# 10        13        22        12        20         4         3        10
#
#     REPWTP73  REPWTP74  REPWTP75  REPWTP76  REPWTP77  REPWTP78  REPWTP79  \
# 1         11        10        11        11        21        25        11
# 2         25        13         3        14         4         4        22
# 3         26        14         4        15         4         4        24
# 9         11        12        23        11         4        16         4
# 10        11        12        22        11         4        15         3
#
#     REPWTP80 stpuma_id  StateFIPS  PUMA_y GEOID10  \
# 1         11    900500        9.0   500.0  900500
# 2         13    900100        9.0   100.0  900100
# 3         14    900100        9.0   100.0  900100
# 9         13    900105        9.0   105.0  900105
# 10        11    900105        9.0   105.0  900105
#
#                                                  NAME Subregion Subregion2  \
# 1                              Litchfield County PUMA        CT         CT
# 2   Danbury, Ridgefield, Bethel, Brookfield, New F...        CT         CT
# 3   Danbury, Ridgefield, Bethel, Brookfield, New F...        CT         CT
# 9   Stratford, Shelton, Trumbull, Newtown & Monroe...        CT         CT
# 10  Stratford, Shelton, Trumbull, Newtown & Monroe...        CT         CT
#
#     Region      County  CountyFIPS
# 1   Region  Litchfield      9005.0
# 2   Region   Fairfield      9001.0
# 3   Region   Fairfield      9001.0
# 9   Region   Fairfield      9001.0
# 10  Region   Fairfield      9001.0

# %%
occ = ['119121','191020','191040','1910XX','192030','194021','194031',\
      '194031','1940XX','172131','172141','172031','1720XX','172041','292010']

# %%
# REDUCE DATA TABLE TO LIFE SCI OCCUPATION CODES
reg_10_occ=reg_10[reg_10['OCCSOC'].isin(occ)]
reg_19_occ=reg_19[reg_19['OCCSOC'].isin(occ)]

# %%
reg_10_occ.shape
# Out:
# (4551, 120)

# %%
# reduce table to just counties and subregions of residence 1 year ago
cols10 = ['CountyName','Subregion','PERWT'] + repwts
cols19 = ['County','Subregion','PERWT'] + repwts
reg_10_occ = reg_10_occ[cols10]
reg_19_occ = reg_19_occ[cols19]

# rename for clarity
#df_in = df_in.rename(columns={'County':'out_co_name','CountyFIP':'out_stco',\
##                              'Subregion5':'out_subreg_5','Subregion7':'out_subreg_7',\
#                              'PERWT':'in_pop'})
    
#df_in.head()

# %% [markdown]
# #### Subregion life sci worker totals

# %%
reg_10_occ_2 = reg_10_occ.groupby('Subregion').sum().reset_index()
reg_10_occ_2
# Out:
#   Subregion    PERWT  REPWTP1  REPWTP2  REPWTP3  REPWTP4  REPWTP5  REPWTP6  \
# 0        CT  10421.0    10877    10270    10266    10358    10341    10884
# 1        LI   9823.0     9962     9899    10057     9835    10058     9838
# 2     LowHV   6027.0     5895     5977     6144     5877     6241     6145
# 3     MidHV   3172.0     3051     3245     3279     2865     3005     3444
# 4      NJIn  30781.0    31064    30105    29888    31501    31404    31509
# 5     NJOut   9929.0    10114     9554    10098    10128     9927    10004
# 6       NYC  25381.0    24906    25204    25327    25262    24551    26112
#
#    REPWTP7  REPWTP8  REPWTP9  REPWTP10  REPWTP11  REPWTP12  REPWTP13  \
# 0    10812    10339    10481     10090     10860     10602     10544
# 1     9612     9889     9452     10228     10117      9848      9715
# 2     6276     5999     6022      5876      6264      6159      6068
# 3     3329     3246     2890      3316      2975      3077      3218
# 4    30554    31968    30799     31031     30606     30852     30968
# 5     9987    10124    10462      9541      9859      9583      9685
# 6    25713    26010    24792     24715     25462     26646     25628
#
#    REPWTP14  REPWTP15  REPWTP16  REPWTP17  REPWTP18  REPWTP19  REPWTP20  \
# 0     10073      9910     10283     10446     10196     10638     10682
# 1     10183      9777      9066      9752     10123      9708      9537
# 2      5719      6101      5851      5955      6276      5943      6209
# 3      3201      3193      3152      3222      3299      3086      3154
# 4     31411     29901     31209     31348     31613     31568     30571
# 5      9900      9746      9792      9577     10024     10347      9951
# 6     25811     26075     26244     25152     26180     25349     25858
#
#    REPWTP21  REPWTP22  REPWTP23  REPWTP24  REPWTP25  REPWTP26  REPWTP27  \
# 0     10226     10284     11204     10115     10225     10658     10774
# 1      9690     10294      9789      9317      9808      9573     10093
# 2      6070      5933      6228      5972      5817      6051      6100
# 3      3256      3239      3101      3122      3227      3176      3277
# 4     30673     30953     30720     30597     30116     29920     30782
# 5      9783      9507      9923      9692     10033     10260     10193
# 6     25654     25303     25350     25357     25130     25179     25585
#
#    REPWTP28  REPWTP29  REPWTP30  REPWTP31  REPWTP32  REPWTP33  REPWTP34  \
# 0     10492     10161     10151     10413     10283     10303     10433
# 1     10094      9445     10260      9591      9665     10112     10036
# 2      6185      6247      5853      6000      5814      6196      5907
# 3      3200      3170      3211      3114      2998      3159      3194
# 4     31087     31016     30825     31436     30644     32026     30460
# 5      9934     10034      9908      9924      9929     10054     10134
# 6     26432     25192     25276     24886     25106     24778     25192
#
#    REPWTP35  REPWTP36  REPWTP37  REPWTP38  REPWTP39  REPWTP40  REPWTP41  \
# 0     10386     10553     10672     10696     10219     10367     10326
# 1      9978      9474      9573      9495      9714      9330     10011
# 2      5672      6271      6016      5745      6274      5854      5804
# 3      3236      3241      3103      3128      3100      3205      3315
# 4     30429     30997     30696     30711     30436     31174     30933
# 5     10104     10070     10153      9836      9968      9724      9905
# 6     25010     24765     25457     25981     25486     25476     24615
#
#    REPWTP42  REPWTP43  REPWTP44  REPWTP45  REPWTP46  REPWTP47  REPWTP48  \
# 0     10822     10619     10472     10655     10455     10327     10683
# 1      9760      9762      9961     10247     10071      9918     10303
# 2      6297      5518      5946      6331      6267      5763      5875
# 3      3411      3177      3124      3243      2977      3196      3231
# 4     30587     31311     31666     30975     30984     30230     30883
# 5      9990     10159     10230      9957      9688     10058      9419
# 6     25828     25096     26024     25944     25927     25294     25396
#
#    REPWTP49  REPWTP50  REPWTP51  REPWTP52  REPWTP53  REPWTP54  REPWTP55  \
# 0     10003     10580     10336     10307     10374     10386     10616
# 1      9839      9841      9424      9716      9782      9772      9472
# 2      5899      5837      6056      6078      5755      6362      6339
# 3      3368      3133      3039      3212      3029      3185      3204
# 4     31121     30977     30705     30355     31062     30719     30401
# 5     10186     10104      9852     10143     10163     10348      9803
# 6     26015     24995     24472     25858     25982     25947     25245
#
#    REPWTP56  REPWTP57  REPWTP58  REPWTP59  REPWTP60  REPWTP61  REPWTP62  \
# 0     10733     10442     10711     10196      9949     10366     10299
# 1      9519      9545      9581     10136      9374      9891      9946
# 2      6173      6007      5950      6074      6082      6299      6017
# 3      2888      3197      3223      3248      2973      3392      3195
# 4     31667     30458     30509     30618     31524     30941     30173
# 5     10034     10257      9880      9969      9561     10049     10014
# 6     25886     26138     25921     24631     24971     25207     25212
#
#    REPWTP63  REPWTP64  REPWTP65  REPWTP66  REPWTP67  REPWTP68  REPWTP69  \
# 0     10521     10524     10191     10225     10347     10217     10247
# 1      9692      9501     10275      9544     10122      9597      9808
# 2      5799      6213      5994      6466      5955      5602      5583
# 3      3099      3046      3260      3097      3125      3137      3323
# 4     30844     31051     32205     30761     31183     30790     30396
# 5      9520      9795      9849      9985      9803      9707      9710
# 6     25673     25010     24815     25108     25114     25545     24817
#
#    REPWTP70  REPWTP71  REPWTP72  REPWTP73  REPWTP74  REPWTP75  REPWTP76  \
# 0     10934     10206     10317     10568     10253     10857     10498
# 1      9802      9581      9978      9903      9929      9807      9460
# 2      6170      5986      6076      6229      5937      6156      6290
# 3      3401      3140      3127      3053      2989      3563      3173
# 4     31416     29767     30534     31171     31129     30802     31444
# 5      9846     10056      9971     10077      9967     10099      9883
# 6     25187     25360     25720     25281     25253     25753     24819
#
#    REPWTP77  REPWTP78  REPWTP79  REPWTP80
# 0     10731     11196     10005     10425
# 1     10041      9565     10182      9662
# 2      6262      6308      6068      6071
# 3      2926      3051      3282      3191
# 4     30536     30402     30935     30249
# 5      9952     10483      9728     10077
# 6     25630     25806     25880     24808

# %%
# calculate standard error, margin of error, cv
# drop replicate weight columns
reg_10_occ_2['worker_se'] = reg_10_occ_2.apply(lambda x: (get_se(x['PERWT'],x[repwts])),axis=1)
reg_10_occ_2['worker_moe'] = reg_10_occ_2.apply(lambda x: (get_moe(x['worker_se'])),axis=1)
reg_10_occ_2['worker_cv'] = reg_10_occ_2.apply(lambda x: (get_cv(x['PERWT'],x['worker_se'])),axis=1)

reg_10_occ_2 = reg_10_occ_2.drop(columns=repwts) 
                            
reg_10_occ_2
# Out:
#   Subregion    PERWT    worker_se   worker_moe  worker_cv
# 0        CT  10421.0   530.476201   872.633351   3.094501
# 1        LI   9823.0   535.353014   880.655709   3.313067
# 2     LowHV   6027.0   400.391683   658.644319   4.038480
# 3     MidHV   3172.0   256.711414   422.290276   4.919785
# 4      NJIn  30781.0  1012.946741  1666.297389   2.000497
# 5     NJOut   9929.0   438.874526   721.948596   2.687008
# 6       NYC  25381.0   959.156687  1577.812750   2.297285

# %% [markdown]
# ### 2019 life sci regional workers

# %%
reg_19_occ_2 = reg_19_occ.groupby('Subregion').sum().reset_index()
reg_19_occ_2
# Out:
#   Subregion    PERWT  REPWTP1  REPWTP2  REPWTP3  REPWTP4  REPWTP5  REPWTP6  \
# 0        CT   8715.0     8855     9111     8886     9015     9359     8628
# 1        LI   8915.0     8978     8985     9265     8884     9036     8641
# 2   Low Hud   4698.0     4861     4610     4711     4791     4680     4661
# 3   Mid Hud   2973.0     2630     3116     2969     2774     2919     3008
# 4     NJ In  28360.0    28545    28413    28987    28535    28318    28314
# 5    NJ Out   6923.0     7094     6850     7050     6489     6542     6877
# 6       NYC  24207.0    22895    23663    24105    24485    24473    24457
#
#    REPWTP7  REPWTP8  REPWTP9  REPWTP10  REPWTP11  REPWTP12  REPWTP13  \
# 0     8676     9165     8441      8784      8142      8816      8461
# 1     8690     9186     8733      8395      9101      8500      8694
# 2     4755     4543     4397      4444      5022      4618      4743
# 3     3067     3029     2720      3049      3166      3238      2984
# 4    28090    28641    28408     28237     28640     28611     28190
# 5     6932     7207     6888      6706      7076      6552      6683
# 6    23364    23826    25070     23773     24786     25077     23526
#
#    REPWTP14  REPWTP15  REPWTP16  REPWTP17  REPWTP18  REPWTP19  REPWTP20  \
# 0      8345      8954      8464      8706      8844      8762      9375
# 1      8992      8543      9417      9009      8696      9294      8629
# 2      4795      4589      4880      4942      4716      4785      4793
# 3      2971      2907      3099      3193      2980      2926      2909
# 4     27917     28141     27504     27763     28761     28483     27715
# 5      7027      6925      6790      7285      7011      6886      7083
# 6     24145     24901     24385     24379     24507     23832     24386
#
#    REPWTP21  REPWTP22  REPWTP23  REPWTP24  REPWTP25  REPWTP26  REPWTP27  \
# 0      8654      8808      8599      8596      8492      9078      8684
# 1      8907      9055      8612      8927      9223      8215      8794
# 2      4947      4680      4657      4698      4401      4751      4482
# 3      3137      3017      2956      3164      2799      2928      2915
# 4     28678     28156     29252     27688     28721     28627     27263
# 5      7044      7103      6874      6749      6696      6762      6932
# 6     24768     24063     24553     24274     25094     24337     24051
#
#    REPWTP28  REPWTP29  REPWTP30  REPWTP31  REPWTP32  REPWTP33  REPWTP34  \
# 0      8496      8735      8491      8962      8714      8600      8271
# 1      8910      8804      8813      9103      9051      8887      9533
# 2      4347      4729      4632      4924      4818      4537      4794
# 3      2942      3160      3276      2916      2986      3055      2959
# 4     28772     27802     28560     28518     28262     28578     28682
# 5      7284      6874      6939      6845      7094      7051      7011
# 6     24310     24372     23834     24235     24981     24208     24449
#
#    REPWTP35  REPWTP36  REPWTP37  REPWTP38  REPWTP39  REPWTP40  REPWTP41  \
# 0      8815      8713      8564      8957      8743      8929      8452
# 1      9371      8885      9464      8781      8622      8776      9304
# 2      4694      4673      4644      4746      4672      4688      4704
# 3      2745      2823      2996      2801      2842      3111      3138
# 4     28567     28154     28190     28580     29196     28068     29243
# 5      6946      7017      6944      6981      7262      7551      7126
# 6     24248     24343     24275     24504     24415     24142     24160
#
#    REPWTP42  REPWTP43  REPWTP44  REPWTP45  REPWTP46  REPWTP47  REPWTP48  \
# 0      8836      8737      8909      8956      8635      8736      8693
# 1      9141      8353      8986      8747      8631      8669      9244
# 2      4808      4962      4658      4569      4823      4632      4790
# 3      3223      2823      2653      2949      3024      2965      2977
# 4     28532     28463     29185     28451     28565     27310     27694
# 5      7328      6617      7045      7276      6684      6809      6638
# 6     24497     23976     24762     24391     24217     24124     24447
#
#    REPWTP49  REPWTP50  REPWTP51  REPWTP52  REPWTP53  REPWTP54  REPWTP55  \
# 0      8439      8440      8691      8813      8929      8761      8442
# 1      8756      9165      8690      9285      8982      8517      9000
# 2      4668      4851      4746      4544      4638      4570      4809
# 3      2736      2871      2872      2860      3113      2896      3101
# 4     27865     28312     28102     28552     28648     27642     28297
# 5      6892      7497      7126      7065      6742      6756      7102
# 6     24930     24580     24593     24266     23684     24173     24665
#
#    REPWTP56  REPWTP57  REPWTP58  REPWTP59  REPWTP60  REPWTP61  REPWTP62  \
# 0      8615      9238      8911      8908      8964      8570      8743
# 1      9437      9179      9083      9116      8563      8829      9161
# 2      4961      4662      4666      4391      5072      4642      4740
# 3      2821      2828      2780      2653      3024      2771      3013
# 4     29012     28485     28463     27774     28301     27834     28797
# 5      7073      6864      6676      6905      6487      7029      6857
# 6     25299     24527     23755     23409     24212     24672     24272
#
#    REPWTP63  REPWTP64  REPWTP65  REPWTP66  REPWTP67  REPWTP68  REPWTP69  \
# 0      8108      8339      8934      9316      9165      8430      8935
# 1      8908      8915      9080      8540      9122      8765      8771
# 2      4364      4485      4651      4619      4528      4633      4835
# 3      3217      3204      3333      3106      2983      3049      3012
# 4     28406     28292     28673     28561     27930     27858     29332
# 5      6706      7044      6510      6916      7145      7222      7099
# 6     24175     24885     24093     24330     23253     24114     23791
#
#    REPWTP70  REPWTP71  REPWTP72  REPWTP73  REPWTP74  REPWTP75  REPWTP76  \
# 0      8627      8471      8317      8580      8771      8670      9062
# 1      8712      8944      8566      8902      8843      9085      9227
# 2      4936      4431      4516      4719      4424      4454      5025
# 3      3233      2832      2934      2976      3090      3090      2928
# 4     29260     27999     27790     28302     27869     28594     28396
# 5      6569      7228      6910      6776      6710      6887      6956
# 6     24085     24557     24126     24639     24136     23681     24515
#
#    REPWTP77  REPWTP78  REPWTP79  REPWTP80
# 0      8733      8563      8664      8219
# 1      8824      8822      8946      8843
# 2      4830      4963      5060      4969
# 3      2975      2929      2848      3139
# 4     27947     29087     28317     27950
# 5      6960      6995      6887      7241
# 6     24582     23533     24310     24060

# %%
# calculate standard error, margin of error, cv
# drop replicate weight columns
reg_19_occ_2['worker_se'] = reg_19_occ_2.apply(lambda x: (get_se(x['PERWT'],x[repwts])),axis=1)
reg_19_occ_2['worker_moe'] = reg_19_occ_2.apply(lambda x: (get_moe(x['worker_se'])),axis=1)
reg_19_occ_2['worker_cv'] = reg_19_occ_2.apply(lambda x: (get_cv(x['PERWT'],x['worker_se'])),axis=1)

reg_19_occ_2 = reg_19_occ_2.drop(columns=repwts) 
                            
reg_19_occ_2
# Out:
#   Subregion    PERWT   worker_se   worker_moe  worker_cv
# 0        CT   8715.0  531.701044   874.648217   3.708807
# 1        LI   8915.0  538.938958   886.554585   3.674958
# 2   Low Hud   4698.0  342.274743   563.041953   4.428901
# 3   Mid Hud   2973.0  302.950739   498.353965   6.194571
# 4     NJ In  28360.0  907.074832  1492.138098   1.944335
# 5    NJ Out   6923.0  445.337905   732.580854   3.910474
# 6       NYC  24207.0  888.603483  1461.752730   2.231522

# %% [markdown]
# ### Merge in & out to create net flow columns
#
# fix up the crosswalk files to make sure this can be done

# %%
reg_19_occ_2.to_excel('../output/lifesci_2019.xlsx')
reg_10_occ_2.to_excel('../output/lifesci_2010.xlsx')
